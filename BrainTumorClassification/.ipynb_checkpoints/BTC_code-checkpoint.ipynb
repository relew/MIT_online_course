# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import cv2
import matplotlib.pyplot as plt 
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D
from tensorflow.keras.optimizers import Adam 
from keras_tuner import RandomSearch
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2023-09-11 10:47:55.034485: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-11 10:47:55.087643: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-11 10:47:55.089105: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-11 10:47:55.950006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load and Prepare Data

# %%
#loading data
train_img = []
train_img_2D = []
train_labels = []

test_img = []
test_labels = []

path_train = ('/mnt/c/Python/IDSS/BTC_inputs/Training/')
path_test = ('/mnt/c/Python/IDSS/BTC_inputs/Testing/')
img_size= 75

#prep data
for i in os.listdir(path_train):
    for j in os.listdir(path_train+i):
        train_img.append (cv2.resize(cv2.imread(path_train+i+'/'+j), (img_size,img_size)))
        train_img_2D.append (cv2.resize(cv2.imread(path_train+i+'/'+j,cv2.IMREAD_GRAYSCALE), (img_size,img_size)))
        train_labels.append(i)
        
for i in os.listdir(path_test):
    for j in os.listdir(path_test+i):
        test_img.append (cv2.resize(cv2.imread(path_test+i+'/'+j), (img_size,img_size))) 
        test_labels.append(i)

train_img = (np.array(train_img))
train_img_2Dx = (np.array(train_img_2D))
test_img = (np.array(test_img))


train_labels_encoded = [0 if category == 'no_tumor' else
                        (1 if category == 'glioma_tumor' else
                         (2 if category=='meningioma_tumor' else
                          3)) for category in list(train_labels)]
test_labels_encoded = [0 if category == 'no_tumor' else
                       (1 if category == 'glioma_tumor' else
                        (2 if category=='meningioma_tumor' else
                         3)) for category in list(test_labels)]

# %%
print("Shape of train: ",(train_img).shape," and shape of test: ", (test_img).shape)
# Out:
# Shape of train:  (2870, 75, 75, 3)  and shape of test:  (394, 75, 75, 3)

# %% [markdown]
# ## Augmenting the data

# %%
img_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True)

img_datagen.fit(train_img)
img_datagen.fit(test_img)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',color='r',y=0.62,x=0.4,alpha=0.8)
for i in set(train_labels):
    j=0
    while True :
        if train_labels[j]==i:
            ax[k].imshow(train_img[j])
            ax[k].set_title(train_labels[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
plt.figure(figsize = (17,8));
lis = ['Train', 'Test']
for i,j in enumerate([train_labels, test_labels]):
    plt.subplot(1,2, i+1);
    datax = []
    labelx = []
    for ix in set(j):
        datax.append(j.count(ix))
        labelx.append(ix)
    plt.pie(datax, labels=labelx, autopct='%.0f%%')
    plt.xlabel(lis[i])

# %%
# class btc():
#     def imNorm(self,im):
#         return (im - np.min(im)) / (np.max(im) - np.min(im))

#     # Z-score image
#     def imZsc(self,im):
#         ret = (im - np.mean(im)) / np.std(im)
#         ret[np.where(ret > 3.0)] = 3.0
#         ret[np.where(ret < -3.0)] = -3.0
#         return ret
    
#     # log transform
#     def imLog(self,im):
#         return self.imNorm(np.log10(im + 1))
    
#     # Laplacian transformation
#     def imLaplacian(self,im):
#         ret = cv2.Laplacian(im, cv2.CV_64F, ksize=21)
#         return self.imNorm(ret)
    
#     # create a histogram equalized image
#     def imHe(self,im):
#         return self.imNorm(cv2.equalizeHist(im))
    
#     # Contrast Limited Adaptive Histogram normalization
#     # clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
#     def imClahe(self,im):
#         return self.imNorm(cv2.createCLAHE(clipLimit=2.0, tileGridSize=(16, 16)).apply(im))
    
#     # Scharr edge filter
#     def imScharr(self,im):
#         return self.imNorm(cv2.Scharr(cv2.Scharr(im, cv2.CV_64F, 1, 0), cv2.CV_64F, 0, 1))

# btc = btc()

# def colFunctions(xx):
#     return [xx/255.0,btc.imNorm(xx),btc.imZsc(xx),btc.imHe(xx),
#             btc.imClahe(xx),btc.imLaplacian(xx),btc.imScharr(xx),btc.imLog(xx)]

# colLabels =['scaled','normalized','zscore','hist.Eq.',
#             'CLAHE','Laplacian','Scharr','Log10']

# print('Min and max values after image processing\n')
# Z = np.array(colFunctions(train_img_2Dx[5,:,:]))
# for i in range(8):
#      img=Z[i,:,:]
#      print(f'{colLabels[i]} min = {np.min(img)}, max = {np.max(img)}')

# %% [markdown]
# ## Modelling

# %%
train_x, val_x, train_y, val_y = train_test_split(np.array(train_img), np.array(train_labels), test_size = 0.1)
train_x.shape, train_y.shape, val_x.shape, val_y.shape
# Out:
# ((2583, 75, 75, 3), (2583,), (287, 75, 75, 3), (287,))

# %%
# Adding padding here to preserve the image shape
# Adding maxpool layer to get those pixels which have the highest intensity. Reduces the image size by 2.
# Took filters of 77 as image size if 300 300 thus it would help it to learn better.
# Taken a dropout layer, to avoid overfitting.


model = tf.keras.Sequential(
        [
          tf.keras.layers.Conv2D(kernel_size=(5,5) ,filters=32, activation='relu', padding='same'),
          tf.keras.layers.MaxPool2D(pool_size=(2,2)),

          tf.keras.layers.Conv2D(kernel_size=(3,3),filters=32, activation='relu', padding='same'),
          tf.keras.layers.MaxPool2D(pool_size=(2,2)),

          tf.keras.layers.Conv2D(kernel_size=(3,3) ,filters=32, activation='relu', padding='same'),
          tf.keras.layers.MaxPool2D(pool_size=(2,2)),

          tf.keras.layers.Conv2D(kernel_size=(3,3) ,filters=64, activation='relu', padding='same'),
          tf.keras.layers.MaxPool2D(pool_size=(2,2)),

          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(128, activation='relu'),
          tf.keras.layers.Dropout(rate=0.5),
          tf.keras.layers.Dense(4, activation='sigmoid')
  ])

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# 2023-09-11 10:49:06.268018: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-11 10:49:06.268666: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
history = model.fit(tf.cast(train_img, tf.float32),
                    np.array(pd.get_dummies(train_labels)),
                    validation_split=0.1, epochs =12, verbose=1, batch_size=32)
# Out:
# Epoch 1/12
# 81/81 [==============================] - 11s 122ms/step - loss: 2.4058 - accuracy: 0.4204 - val_loss: 1.8830 - val_accuracy: 0.2822
# Epoch 2/12
# 81/81 [==============================] - 10s 125ms/step - loss: 0.9919 - accuracy: 0.5544 - val_loss: 1.5686 - val_accuracy: 0.2753
# Epoch 3/12
# 81/81 [==============================] - 9s 109ms/step - loss: 0.8714 - accuracy: 0.6152 - val_loss: 1.2813 - val_accuracy: 0.3031
# Epoch 4/12
# 81/81 [==============================] - 9s 112ms/step - loss: 0.7807 - accuracy: 0.6574 - val_loss: 1.0484 - val_accuracy: 0.4355
# Epoch 5/12
# 81/81 [==============================] - 9s 112ms/step - loss: 0.7286 - accuracy: 0.6852 - val_loss: 1.1709 - val_accuracy: 0.3868
# Epoch 6/12
# 81/81 [==============================] - 9s 110ms/step - loss: 0.6814 - accuracy: 0.7007 - val_loss: 0.7082 - val_accuracy: 0.7387
# Epoch 7/12
# ...

# %%
# The image from data generator is of type 'uint8', you need to type cast it to 'float32'.
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("modelv1.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

history = model.fit(tf.cast(train_img, tf.float32),
                    np.array(pd.get_dummies(train_labels)),
                    validation_split=0.1, epochs =12, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# 2023-09-11 10:32:40.888946: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 193725000 exceeds 10% of free system memory.
# 2023-09-11 10:32:44.497056: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 774900000 exceeds 10% of free system memory.
# 2023-09-11 10:32:52.856199: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 697410000 exceeds 10% of free system memory.
# 2023-09-11 10:32:55.497154: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 77490000 exceeds 10% of free system memory.
# Epoch 1/12
# 2023-09-11 10:33:01.006182: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 92160000 exceeds 10% of free system memory.

# %% [markdown]
# # Check output

# %%
#filterwarnings('ignore')

epochs = [i for i in range(12)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold',
             fontname='monospace',color='r',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, marker='o',markerfacecolor='w',color='g',
           label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, marker='o',markerfacecolor='w',color='r',
           label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss, marker='o',markerfacecolor='w',color='g',
           label ='Training Loss')
ax[1].plot(epochs, val_loss, marker='o',markerfacecolor='w',color='r',
           label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')
fig.show()

# %%
pred = model.predict(test_img)
pred = np.argmax(pred,axis=1)
#y_test_new = np.argmax(np.array(test_labels_encoded),axis=1)
# Out:
# 13/13 [==============================] - 0s 21ms/step

# %%
print(classification_report(test_labels_encoded,pred,target_names=['no_tumor','glioma_tumor','meningioma_tumor','pituitary_tumor']))
# Out:
#                   precision    recall  f1-score   support
#
#         no_tumor       0.00      0.00      0.00       105
#     glioma_tumor       0.16      0.19      0.17       100
# meningioma_tumor       0.17      0.32      0.22       115
#  pituitary_tumor       0.97      0.51      0.67        74
#
#         accuracy                           0.24       394
#        macro avg       0.33      0.26      0.27       394
#     weighted avg       0.27      0.24      0.24       394

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(test_labels_encoded,pred),ax=ax,
            xticklabels=['no_tumor','glioma_tumor','meningioma_tumor','pituitary_tumor'],
            yticklabels=['no_tumor','glioma_tumor','meningioma_tumor','pituitary_tumor'],annot=True,
            cmap='Blues',alpha=0.7,linewidths=2,linecolor='k',fmt='g')
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color='k',y=0.92,x=0.28,alpha=0.8)
plt.ylabel('True')
plt.xlabel('Predicted')

plt.show()

# %% [markdown]
# ## test on random test img

# %%
set(train_labels)
# Out:
# {'glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor'}

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm

labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']


X_train = []
y_train = []

X_test = []
y_test = []

image_size = 75
for i in labels:
    folderPath = os.path.join('/mnt/c/Python/IDSS/BTC_inputs','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('/mnt/c/Python/IDSS/BTC_inputs','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_test.append(img)
        y_test.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test= np.array(X_test)
y_test = np.array(y_test)
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 74/74 [00:01<00:00, 58.97it/s]

# %%
from sklearn.utils import shuffle

X_train, y_train = shuffle(X_train,y_train, random_state=101)
X_train.shape
# Out:
# (2870, 75, 75, 3)

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train, test_size=0.1,random_state=101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X_train,X_val,y_train,y_val = train_test_split(X_train,y_train, test_size=0.1,random_state=101)
#
# NameError: name 'train_test_split' is not defined

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_val_new = []
for i in y_val:
    y_val_new.append(labels.index(i))
y_val = y_val_new
y_val = tf.keras.utils.to_categorical(y_val)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 y_train_new = []
#       2 for i in y_train:
# ----> 3     y_train_new.append(labels.index(i))
#       4 y_train = y_train_new
#       5 y_train = tf.keras.utils.to_categorical(y_train)
#
# ValueError: array([0., 0., 1., 0.], dtype=float32) is not in list

# %%
from tensorflow.keras.applications import EfficientNetB0, InceptionResNetV2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint

effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# 2023-09-11 09:23:36.250031: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-11 09:23:36.250720: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnetv2.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =10, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/10
# 73/73 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.7788
# Epoch 1: val_accuracy improved from -inf to 0.73745, saving model to effnetv2.h5
# 73/73 [==============================] - 83s 912ms/step - loss: 0.6039 - accuracy: 0.7788 - val_loss: 0.6925 - val_accuracy: 0.7375 - lr: 0.0010
# Epoch 2/10
# 73/73 [==============================] - ETA: 0s - loss: 0.2929 - accuracy: 0.8916
# Epoch 2: val_accuracy improved from 0.73745 to 0.85714, saving model to effnetv2.h5
# 73/73 [==============================] - 64s 879ms/step - loss: 0.2929 - accuracy: 0.8916 - val_loss: 0.5374 - val_accuracy: 0.8571 - lr: 0.0010
# Epoch 3/10
# 73/73 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9277
# Epoch 3: val_accuracy improved from 0.85714 to 0.89575, saving model to effnetv2.h5
# 73/73 [==============================] - 61s 839ms/step - loss: 0.2031 - accuracy: 0.9277 - val_loss: 0.4723 - val_accuracy: 0.8958 - lr: 0.0010
# ...

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 13/13 [==============================] - 2s 123ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.19      0.32       100
#            1       0.68      1.00      0.81       105
#            2       0.68      0.99      0.81       115
#            3       1.00      0.72      0.83        74
#
#     accuracy                           0.74       394
#    macro avg       0.84      0.72      0.69       394
# weighted avg       0.82      0.74      0.69       394

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),
            ax=ax,xticklabels=labels,
            yticklabels=labels,annot=True,
           cmap=colors_green[::-1],alpha=0.7,linewidths=2,linecolor=colors_dark[3],fmt='g')
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',color=colors_dark[1],y=0.92,x=0.28,alpha=0.8)

plt.show()
